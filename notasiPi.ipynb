# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definisikan Pi
pi = np.pi

# 2. Buat rentang x dari -4*pi sampai 4*pi dengan 400 titik agar halus
x = np.linspace(-4*pi, 4*pi, 400)

# 3. Hitung y (sin(x)/x)
# Kita gunakan np.sinc(x/pi) dari numpy atau manual seperti di bawah:
y = np.sin(x) / x

# 4. Plot grafik
plt.figure(figsize=(10, 5))
plt.plot(x, y, label=r'$f(x) = \frac{\sin(x)}{x}$')

# Tambahkan garis bantu dan label
plt.axhline(0, color='black', lw=1) # Garis horizontal y=0
plt.axvline(0, color='black', lw=1) # Garis vertikal x=0
plt.title("Grafik Fungsi Sinc")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)

# 5. Tampilkan
plt.show()

# %%
x = np.linspace (0,4*np.pi, 10)
y = np.exp(-x)*np.sin(x)
plt.figure()
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(0,4*np.pi,10)
y = np.exp(-x)*np.sin(x)
z = np.exp(-x)
plt.figure()
plt.plot(x,y)
plt.plot(x,z, 'r--', label='$ e^{-x}$')
plt.legend(['y','z'])

# %%
import numpy as np

# Membuat array 3D berukuran 2x2x3
array3d = np.array([
    [[3, 5, 4], [7, 8, 9]],          # Blok 0 (Daftar pertama)
    [[10, 11, 12], [13, 14, 15]]      # Blok 1 (Daftar kedua)
])

print(array3d)

# Menampilkan baris kedua (indeks 1) dari blok pertama (indeks 0)
# Hasilnya: [7, 8, 9]
print("Nilai pada daftar kedua dalam daftar pertama: {}".format(array3d[0, 1]))
# Out:
# [[[ 3  5  4]
#   [ 7  8  9]]
#
#  [[10 11 12]
#   [13 14 15]]]
# Nilai pada daftar kedua dalam daftar pertama: [7 8 9]
