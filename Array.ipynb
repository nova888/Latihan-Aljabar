# %%
import numpy as np

nilai = np.array ([
    [10, 20, 30],
    [20, 30, 40],
    [40, 50, 50]
])

print (nilai.shape)
# Out:
# (3, 3)

# %%
nilai = np.array ([80, 85, 90, 95, 88])

#tambah nilai 5
print ("tambah +5 :" , nilai + 5)

#Kalikan 2 semua
print ("dikali 2: ", nilai * 2)

#operasi antar array
nilai1 = np.array([88, 85, 90])
nilai2 = np.array([75, 90, 95])
print("perkalian array: ", nilai1 * nilai2)
# Out:
# tambah +5 : [ 85  90  95 100  93]
# dikali 2:  [160 170 180 190 176]
# perkalian array:  [6600 7650 8550]
