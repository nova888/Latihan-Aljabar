# %%
import os, sys
pathname = os.path.dirname(sys.argv[0])
fullpath = os.path.abspath(pathname)
os.chdir(fullpath)

# %%
import os

from IPython.display import Image
I = Image(filename = 'bulan.jpeg')
I

# %%
print(os.listdir())
# Out:
# ['wcwidth-0.2.5.dist-info', 'httpcore', 'typing_extensions.py', 'comm-0.2.1.dist-info', 'hpack', 'kiwisolver', 'python_json_logger-3.2.1.dist-info', 'pip', 'jupyter_core-5.7.2.dist-info', 'tensorboard_data_server-0.7.0.dist-info', 'executing', 'pytz-2025.2.dist-info', 'mdurl-0.1.2.dist-info', 'attr', 'joblib-1.4.2.dist-info', 'terminado-0.17.1.dist-info', 'parso', 'prompt_toolkit-3.0.43.dist-info', 'cffi-1.17.1.dist-info', 'socks.py', 'scipy', 'keras-3.9.0.dist-info', 'httpcore-1.0.2.dist-info', 'argon2', 'wrapt-1.17.2.dist-info', 'pygments', 'matplotlib_inline', 'pyzmq-26.2.0.dist-info', 'scipy.libs', 'matplotlib-3.10.1.dist-info', 'grpcio-1.67.1.dist-info', 'urllib3-2.4.0.dist-info', 'brotli.py', 'babel', 'pandocfilters.py', 'cffi', 'IPython', 'bs4', 'tinycss2', 'Brotli-1.1.0.dist-info', 'termcolor', 'requests-2.32.3.dist-info', 'rfc3986_validator-0.1.1.dist-info', 'pycparser', 'typing_extensions-4.13.2.dist-info', 'absl_py-2.2.0.dist-info', 'json5-0.9.25.dist-info', 'babel-2.16.0.
# ...

# %%
import os

# Melihat folder aktif saat ini
print(f"Lokasi aktif: {os.getcwd()}")

# Melihat daftar file yang ada di folder tersebut
print("Daftar file di folder ini:")
print(os.listdir())
# Out:
# Lokasi aktif: /home/invoker/anaconda3/envs/tensor2/lib/python3.11/site-packages
# Daftar file di folder ini:
# ...
